# %% [markdown]
# # Extract realiable news in spanish language, preferably from Spain
#
# False news extracted from the FNC corpus has an obvious deficiency of true news, to compensate for this we will extract reliable news from trusted newspapers.
#
# We are going to extract the news from this dataset of 342.000 news in spanish: https://webhose.io/free-datasets/spanish-news-articles/. These news were crawled on 2016 and it is a zip with 342.000 of json files.
#
# 1. Unzip and merge all the json files into a pandas dataframe.
#
# 2. Drop the unnecessary data
#
# 3. Explore the news sources
#
# 4. Take only the reliable sources
#
# 5. Classify the news according to its topic which is usually specified in the url
#
# 6. Drop the news that are too short and export as csv

# %% [markdown]
# ### 1. Unzip and merge all the json files into a pandas dataframe.

# %%
# %%time
import pandas as pd
import json  
import zipfile

list_result = []

with zipfile.ZipFile("../data/645_webhose-2016-10_20170904091850.zip", "r") as z:
    for file in z.namelist():  
        with z.open(file) as f:  
            data = f.read()  
            list_result.append(json.loads(data.decode("utf-8")))
            
df = pd.DataFrame(list_result)
# Out:
# CPU times: user 59.4 s, sys: 40.5 s, total: 1min 39s
# Wall time: 1min 49s

# %%
df.head()
# Out:
#   organizations                                      uuid  \
# 0            []  f9ddd9641788b2f5fcadbae6e2ce7a7f84d555b7
# 1            []  e442424ed01c6c617b46f5b76307c9423dbb0fe5
# 2            []  b5eee3b98a2740402ef08a334ca83f796601b55a
# 3            []  b0e5edd25798fdab23983913a329caf1ef6f851f
# 4            []  03d016c67ff762b0e6ff03b5d9e72aec76e60721
#
#                                               thread  \
# 0  {'social': {'gplus': {'shares': 0}, 'pinterest...
# 1  {'social': {'gplus': {'shares': 0}, 'pinterest...
# 2  {'social': {'gplus': {'shares': 0}, 'pinterest...
# 3  {'social': {'gplus': {'shares': 0}, 'pinterest...
# 4  {'social': {'gplus': {'shares': 0}, 'pinterest...
#
#                                        author  \
# 0  lanacion.com (noreply@lanacionline.com.ar)
# 1
# 2                             el-nacional.com
# 3                             El Nacional Web
# 4
#
#                                                  url  ord_in_thread  \
# 0  http://www.lanacion.com.ar/1943326-detras-de-e...              0
# 1  http://www.coches.net/nissan-terrano-30di-spor...              0
# 2  http://www.el-nacional.com/GDA/Hijos-Chapo-sos...              0
# 3  http://www.el-nacional.com/escenas/Pelicula-Am...              0
# 4  http://mx.reuters.com/article/topNews/idMXL2N1...              0
#
#                                                title locations  \
# 0  Detrás de escena, Moyano, Barrionuevo y Caló j...        []
# 1  nissan terrano 4x4 3.0di sport 5p Diesel de co...        []
# 2  Hijos de El Chapo, sospechosos de emboscada qu...        []
# 3          Película El Amparo ganó premio en Francia        []
# 4  ACTUALIZA 3-Clinton busca mantener a Trump a l...        []
#
#                                             entities highlightText language  \
# 0  {'persons': [], 'locations': [], 'organization...                spanish
# 1  {'persons': [], 'locations': [], 'organization...                spanish
# 2  {'persons': [], 'locations': [], 'organization...                spanish
# 3  {'persons': [], 'locations': [], 'organization...                spanish
# 4  {'persons': [], 'locations': [], 'organization...                spanish
#
#   persons                                               text external_links  \
# 0      []  Recibí por mail las noticias que impactan Detr...             []
# 1      []  Garantía 12 meses (1 año) Comentarios del anun...             []
# 2      []  Cinco militares mexicanos murieron y 10 result...             []
# 3      []  EL NACIONAL WEB 1 de octubre 2016 - 03:58 pm L...             []
# 4      []  ACTUALIZA 3-Clinton busca mantener a Trump a l...             []
#
#                        published                        crawled highlightTitle
# 0  2016-10-02T11:00:00.000+03:00  2016-10-02T08:38:50.999+03:00
# 1  2016-10-02T08:00:00.000+03:00  2016-10-02T14:02:34.228+03:00
# 2  2016-10-02T05:34:00.000+03:00  2016-10-02T05:07:30.864+03:00
# 3  2016-10-02T04:02:00.000+03:00  2016-10-01T23:02:25.864+03:00
# 4  2016-09-28T10:46:00.000+03:00  2016-10-02T10:48:11.329+03:00

# %% [markdown]
# ### 2. Drop the unnecessary data

# %%
df.columns
# Out:
# Index(['organizations', 'uuid', 'thread', 'author', 'url', 'ord_in_thread',
#        'title', 'locations', 'entities', 'highlightText', 'language',
#        'persons', 'text', 'external_links', 'published', 'crawled',
#        'highlightTitle'],
#       dtype='object')

# %%
df = df.drop(['organizations', 'uuid', 'thread', 'ord_in_thread', 'locations', 'entities', 'highlightText', 'language',
                'persons', 'external_links', 'published', 'crawled', 'highlightTitle'] , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-8e8557546799> in <module>
#       1 df = df.drop(['organizations', 'uuid', 'thread', 'ord_in_thread', 'locations', 'entities', 'highlightText', 'language',
# ----> 2                 'persons', 'external_links', 'published', 'crawled', 'highlightTitle'] , axis = 1)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3910                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3911             else:
# -> 3912                 new_axis = axis.drop(labels, errors=errors)
#    3913             result = self.reindex(**{axis_name: new_axis})
#    3914
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5274         if mask.any():
#    5275             if errors != "ignore":
# -> 5276                 raise KeyError(f"{labels[mask]} not found in axis")
#    5277             indexer = indexer[~mask]
#    5278         return self.delete(indexer)
#
# KeyError: "['organizations' 'uuid' 'thread' 'ord_in_thread' 'locations' 'entities'\n 'highlightText' 'language' 'persons' 'external_links' 'published'\n 'crawled' 'highlightTitle'] not found in axis"

# %%
df.head()
# Out:
#                                        author  \
# 0  lanacion.com (noreply@lanacionline.com.ar)
# 1
# 2                             el-nacional.com
# 3                             El Nacional Web
# 4
#
#                                                  url  \
# 0  http://www.lanacion.com.ar/1943326-detras-de-e...
# 1  http://www.coches.net/nissan-terrano-30di-spor...
# 2  http://www.el-nacional.com/GDA/Hijos-Chapo-sos...
# 3  http://www.el-nacional.com/escenas/Pelicula-Am...
# 4  http://mx.reuters.com/article/topNews/idMXL2N1...
#
#                                                title  \
# 0  Detrás de escena, Moyano, Barrionuevo y Caló j...
# 1  nissan terrano 4x4 3.0di sport 5p Diesel de co...
# 2  Hijos de El Chapo, sospechosos de emboscada qu...
# 3          Película El Amparo ganó premio en Francia
# 4  ACTUALIZA 3-Clinton busca mantener a Trump a l...
#
#                                                 text
# 0  Recibí por mail las noticias que impactan Detr...
# 1  Garantía 12 meses (1 año) Comentarios del anun...
# 2  Cinco militares mexicanos murieron y 10 result...
# 3  EL NACIONAL WEB 1 de octubre 2016 - 03:58 pm L...
# 4  ACTUALIZA 3-Clinton busca mantener a Trump a l...

# %% [markdown]
# ### 3. Explore the news sources

# %%
df.groupby('author').size().sort_values(ascending = False)
# Out:
# author
#                                                        164840
# EUROPA PRESS                                            11174
# Biobiochile - La Red De Prensa M S Grande De Chile.      5380
# Europa Press                                             4493
# lanacion.com (noreply@lanacionline.com.ar)               4331
#                                                         ...
# Mariao1                                                     1
# Mariano Vidal                                               1
# mansanrod                                                   1
# Mariano S Nchez Soler                                       1
# ne0bi0                                                      1
# Length: 21381, dtype: int64

# %%
# We want reliable news from spain. So we need to drop news that aren't from spain and those newspaper that are not reliable.

rows_to_drop = df[(df['author'] == '') |
                   (df['author'] == 'Biobiochile - La Red De Prensa M S Grande De Chile.') |
                   (df['author'] == 'lanacion.com (noreply@lanacionline.com.ar)') |
                   (df['author'] == 'esglobal') |
                   (df['author'] == 'marca.com') |
                   (df['author'] == 'ap') |
                   (df['author'] == 'prensalibre.com') |
                   (df['author'] == '(lavozdigital)') |
                   (df['author'] == 'excelsior.com.mx') |
                   (df['author'] == 'abc.es') |
                   (df['author'] == 'el-nacional.com') |
                   (df['author'] == 'Clarin.com') |
                   (df['author'] == 'Ol') |
                   (df['author'] == 'emol.com') |
                   (df['author'] == 'lanacion') |
                   (df['author'] == 'lanacion.com') |
                   (df['author'] == 'Casa Editorial El Tiempo') |
                   (df['author'] == 'nacion.com') |
                   (df['author'] == 'Redacción') |
                   (df['author'] == 'El Nacional Web') |
                   (df['author'] == 'Noticia Al Dia') |
                   (df['author'] == 'RT en español') |
                   (df['author'] == 'Milenio Digital') |
                   (df['author'] == 'mundod') |
                   (df['author'] == 'Cadena Ser') |
                   (df['author'] == 'Sevilla') |
                   (df['author'] == '(sevilla)') |
                   (df['author'] == 'Todo Noticias') |
                   (df['author'] == 'AFP') |
                   (df['author'] == 'Associated Press') |
                   (df['author'] == 'sojourngsd.org') |
                   (df['author'] == 'hola.com') |
                   (df['author'] == 'Redacci N') |
                   (df['author'] == 'Agencias') |
                   (df['author'] == 'Noticieros Televisa') |
                   (df['author'] == 'Getty Images') |
                   (df['author'] == '(abc)')].index
            
df2 = df.drop(rows_to_drop)
df2.reset_index(inplace = True, drop = True)

df2.groupby('author').size().sort_values(ascending = False)
# Out:
# author
# EUROPA PRESS                       11174
# Europa Press                        4493
# EFE                                 2132
# El País                              830
# Redacción , Barcelona                566
#                                    ...
# PATRICK WHITTLE                        1
# PATRICIA MARTÍN / MADRID               1
# PATRICIA MARTÍN                        1
# PATRICIA LÓPEZ\n@patricialopezl        1
# "BSS"                                  1
# Length: 21346, dtype: int64

# %% [markdown]
# ### 4. Take only the reliable sources

# %%
df2 = df[(df['author'] == 'EUROPA PRESS') | (df['author'] == 'Europa Press') | (df['author'] == 'EUROPA PRESS')]
df2.reset_index(inplace = True, drop = True)
df2
# Out:
#              author                                                url  \
# 0      Europa Press  http://www.eldiario.es/norte/euskadi/entidades...
# 1      Europa Press  http://www.eldiario.es/norte/euskadi/Portugale...
# 2      EUROPA PRESS  http://www.europapress.es/navarra/noticia-lune...
# 3      EUROPA PRESS  http://www.20minutos.es/noticia/2852917/0/fest...
# 4      Europa Press  http://www.europapress.es/videos/video-javier-...
# ...             ...                                                ...
# 15662  EUROPA PRESS  http://www.europapress.es/economia/macroeconom...
# 15663  Europa Press  http://www.europapress.es/desconecta/curiosity...
# 15664  EUROPA PRESS  http://www.europapress.es/cultura/exposiciones...
# 15665  EUROPA PRESS  http://www.europapress.es/deportes/baloncesto-...
# 15666  EUROPA PRESS  http://www.europapress.es/cantabria/noticia-ni...
#
#                                                    title  \
# 0      Más de cien entidades participarán en el Foro ...
# 1      Portugalete acoge este domingo la Gladiator He...
# 2      El lunes se iniciará el vaciado del lago de Me...
# 3      El festival multidisciplinar 'Granada Noir' ar...
# 4      Javier Fernández, presidente de la gestora del...
# ...                                                  ...
# 15662  Las ventas del comercio minorista moderan su c...
# 15663  5 vídeos de sustos aterradores para celebrar H...
# 15664  Un español en la National Gallery de Escocia e...
# 15665                     Pau Ribas, nueve meses de baja
# 15666  La niebla en el Seve Ballesteros obliga a desv...
#
#                                                     text
# 0      Euskadi Más de cien entidades participarán en ...
# 1      Euskadi Portugalete acoge este domingo la Glad...
# 2      PAMPLONA, 2 Oct. (EUROPA PRESS) -    El Ayunta...
# 3      PP pide explicaciones a Junta por "recorte" de...
# 4      Hemeroteca \nPortal de actualidad y noticias d...
# ...                                                  ...
# 15662  Las ventas del comercio minorista aumentaron u...
# 15663  5 vídeos de sustos aterradores para celebrar H...
# 15664  El dramaturgo español Pablo Valcarce (Pablo Fe...
# 15665  El jugador del FC Barcelona Lassa Pau Ribas fu...
# 15666  La densa niebla que continúa este lunes asenta...
#
# [15667 rows x 4 columns]

# %% [markdown]
# ### 5. Classify the news according to its topic, specified in the url

# %%
# Now let's categorize topics and drop urls that not matches the author
list_topic = []
list_source = []
list_headline = []
list_text = []
list_link = []
df3 = pd.DataFrame()

for n, row in df2.iterrows():
    if (df2.loc[n, 'url']).find('politica') >= 1:
        list_topic.append('Politics')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
    
    elif (df2.loc[n, 'url']).find('educacion') >= 1:
        list_topic.append('Education')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
    
    elif (df2.loc[n, 'url']).find('salud') >= 1:
        list_topic.append('Health')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
        
    elif (df2.loc[n, 'url']).find('internacional') >= 1:
        list_topic.append('Politics')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
        
    elif (df2.loc[n, 'url']).find('economia') >= 1:
        list_topic.append('Economy')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
        
    elif (df2['url'].iloc[n]).find('deportes') >= 1:
        list_topic.append('Sports')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
        
    elif (df2.loc[n, 'url']).find('ciencia') >= 1:
        list_topic.append('Science')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
        
    elif (df2.loc[n, 'url']).find('cultura') >= 1:
        list_topic.append('Entertainment')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])
        
    elif (df2.loc[n, 'url']).find('sociedad') >= 1:
        list_topic.append('Society')
        list_source.append(df2['author'].iloc[n])
        list_headline.append(df2['title'].iloc[n])
        list_text.append(df2['text'].iloc[n])
        list_link.append(df2['url'].iloc[n])

df3['Topic'] = list_topic
df3['Source'] = list_source
df3['Headline'] = list_headline
df3['Text'] = list_text
df3['Link'] = list_link
df3['Source'] = df3['Source'].str.replace('EUROPA PRESS', 'Europa Press')

df3
# Out:
#               Topic        Source  \
# 0     Entertainment  Europa Press
# 1           Economy  Europa Press
# 2          Politics  Europa Press
# 3           Society  Europa Press
# 4          Politics  Europa Press
# ...             ...           ...
# 4601        Economy  Europa Press
# 4602         Sports  Europa Press
# 4603        Economy  Europa Press
# 4604  Entertainment  Europa Press
# 4605         Sports  Europa Press
#
#                                                Headline  \
# 0     El festival multidisciplinar 'Granada Noir' ar...
# 1     La confianza del consumidor baja 6,3 puntos en...
# 2     Ban Ki Moon pide reanudar las conversaciones d...
# 3     Víctimas y automovilistas ven "positivo" el de...
# 4     La CUP pedirá adelantar el referéndum a julio ...
# ...                                                 ...
# 4601  Los TCP rechazan la oferta de Eurowings y amen...
# 4602                 Gasquet logra el título en Amberes
# 4603  Las ventas del comercio minorista moderan su c...
# 4604  Un español en la National Gallery de Escocia e...
# 4605                     Pau Ribas, nueve meses de baja
#
#                                                    Text  \
# 0     PP pide explicaciones a Junta por "recorte" de...
# 1     La confianza del consumidor baja 6,3 puntos en...
# 2     04 Octubre 2016 \n"Insto firmemente a reanudar...
# 3     Asociaciones de víctimas, automovilistas y mot...
# 4     El diputado de la CUP, Albert Botrán, ha expli...
# ...                                                 ...
# 4601  El sindicato de tripulantes de cabina alemán U...
# 4602  El tenista francés Richard Gasquet se ha impue...
# 4603  Las ventas del comercio minorista aumentaron u...
# 4604  El dramaturgo español Pablo Valcarce (Pablo Fe...
# 4605  El jugador del FC Barcelona Lassa Pau Ribas fu...
#
#                                                    Link
# 0     http://www.20minutos.es/noticia/2852917/0/fest...
# 1     http://www.europapress.es/economia/macroeconom...
# 2     http://www.europapress.es/internacional/notici...
# 3     http://www.europapress.es/sociedad/noticia-vic...
# 4     http://www.europapress.es/catalunya/noticia-cu...
# ...                                                 ...
# 4601  http://www.europapress.es/economia/red-empresa...
# 4602  http://www.europapress.es/deportes/tenis-00166...
# 4603  http://www.europapress.es/economia/macroeconom...
# 4604  http://www.europapress.es/cultura/exposiciones...
# 4605  http://www.europapress.es/deportes/baloncesto-...
#
# [4606 rows x 5 columns]

# %%
df3['Category'] = 'True'
df3
# Out:
#               Topic        Source  \
# 0     Entertainment  Europa Press
# 1           Economy  Europa Press
# 2          Politics  Europa Press
# 3           Society  Europa Press
# 4          Politics  Europa Press
# ...             ...           ...
# 4601        Economy  Europa Press
# 4602         Sports  Europa Press
# 4603        Economy  Europa Press
# 4604  Entertainment  Europa Press
# 4605         Sports  Europa Press
#
#                                                Headline  \
# 0     El festival multidisciplinar 'Granada Noir' ar...
# 1     La confianza del consumidor baja 6,3 puntos en...
# 2     Ban Ki Moon pide reanudar las conversaciones d...
# 3     Víctimas y automovilistas ven "positivo" el de...
# 4     La CUP pedirá adelantar el referéndum a julio ...
# ...                                                 ...
# 4601  Los TCP rechazan la oferta de Eurowings y amen...
# 4602                 Gasquet logra el título en Amberes
# 4603  Las ventas del comercio minorista moderan su c...
# 4604  Un español en la National Gallery de Escocia e...
# 4605                     Pau Ribas, nueve meses de baja
#
#                                                    Text  \
# 0     PP pide explicaciones a Junta por "recorte" de...
# 1     La confianza del consumidor baja 6,3 puntos en...
# 2     04 Octubre 2016 \n"Insto firmemente a reanudar...
# 3     Asociaciones de víctimas, automovilistas y mot...
# 4     El diputado de la CUP, Albert Botrán, ha expli...
# ...                                                 ...
# 4601  El sindicato de tripulantes de cabina alemán U...
# 4602  El tenista francés Richard Gasquet se ha impue...
# 4603  Las ventas del comercio minorista aumentaron u...
# 4604  El dramaturgo español Pablo Valcarce (Pablo Fe...
# 4605  El jugador del FC Barcelona Lassa Pau Ribas fu...
#
#                                                    Link Category
# 0     http://www.20minutos.es/noticia/2852917/0/fest...     True
# 1     http://www.europapress.es/economia/macroeconom...     True
# 2     http://www.europapress.es/internacional/notici...     True
# 3     http://www.europapress.es/sociedad/noticia-vic...     True
# 4     http://www.europapress.es/catalunya/noticia-cu...     True
# ...                                                 ...      ...
# 4601  http://www.europapress.es/economia/red-empresa...     True
# 4602  http://www.europapress.es/deportes/tenis-00166...     True
# 4603  http://www.europapress.es/economia/macroeconom...     True
# 4604  http://www.europapress.es/cultura/exposiciones...     True
# 4605  http://www.europapress.es/deportes/baloncesto-...     True
#
# [4606 rows x 6 columns]

# %% [markdown]
# ### 6. Drop the news that are too short and export as csv

# %%
import spacy
import re
nlp = spacy.load('es_core_news_lg')

for n, row in df3.iterrows(): 
    text = df3.loc[n, 'Text']  
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"http", "", text)
    doc = nlp(text)
    
    sents = 0
    words = 0

    for sentence in doc.sents:
        sents += 1
        for token in sentence:
            words += 1
    
    if words <= 536 and sents <= 16:
        df3.drop(n, inplace = True)
    
    else:
        pass
    
df3.reset_index(inplace = True, drop = True)
df3
# Out:
#               Topic        Source  \
# 0     Entertainment  Europa Press
# 1           Society  Europa Press
# 2           Economy  Europa Press
# 3         Education  Europa Press
# 4          Politics  Europa Press
# ...             ...           ...
# 1470         Sports  Europa Press
# 1471        Economy  Europa Press
# 1472         Sports  Europa Press
# 1473  Entertainment  Europa Press
# 1474        Economy  Europa Press
#
#                                                Headline  \
# 0     El festival multidisciplinar 'Granada Noir' ar...
# 1     Víctimas y automovilistas ven "positivo" el de...
# 2     Nueve secretos para invertir con éxito de Garc...
# 3     El Consell Escolar inicia un debate "sin restr...
# 4     Los colombianos comienzan a votar este domingo...
# ...                                                 ...
# 1470  Hamilton manda en los primeros libres; Sainz y...
# 1471  El superávit por cuenta corriente se duplica e...
# 1472  Clasificación de la carrera, del Mundial de Pi...
# 1473  El Reina Sofía expone su 'fondo de armario' de...
# 1474  Las ventas del comercio minorista moderan su c...
#
#                                                    Text  \
# 0     PP pide explicaciones a Junta por "recorte" de...
# 1     Asociaciones de víctimas, automovilistas y mot...
# 2     Nueve secretos para invertir con éxito de Garc...
# 3     El Consell Escolar de Catalunya (CEC) ha abier...
# 4     Los colombianos, con su presidente, Juan Manue...
# ...                                                 ...
# 1470  El piloto inglés Lewis Hamilton (Mercedes) fue...
# 1471  La balanza por cuenta corriente, que mide los ...
# 1472  Esta es la clasificación del Gran Premio de Ja...
# 1473  El Museo Reina Sofía inaugura este martes 25 d...
# 1474  Las ventas del comercio minorista aumentaron u...
#
#                                                    Link Category
# 0     http://www.20minutos.es/noticia/2852917/0/fest...     True
# 1     http://www.europapress.es/sociedad/noticia-vic...     True
# 2     http://www.europapress.es/economia/noticia-nue...     True
# 3     http://www.europapress.es/catalunya/noticia-co...     True
# 4     http://www.europapress.es/internacional/notici...     True
# ...                                                 ...      ...
# 1470  http://www.europapress.es/deportes/formula1-00...     True
# 1471  http://www.europapress.es/economia/macroeconom...     True
# 1472  http://www.europapress.es/deportes/formula1-00...     True
# 1473  http://www.europapress.es/cultura/exposiciones...     True
# 1474  http://www.europapress.es/economia/macroeconom...     True
#
# [1475 rows x 6 columns]

# %%
df3.to_csv('../data/reliable_spanish_news.csv', encoding = 'utf-8', index = False)
